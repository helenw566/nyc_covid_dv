# %%
import pandas as pd
import numpy as np
import psycopg2
import os
from dotenv import load_dotenv

# %%
# Load AWS Keys
load_dotenv()
user = os.environ.get('username')
pw = os.environ.get('password')

# %%
#connecting to database

# ============================================================
# REPLACE THESE WITH YOUR ACTUAL CREDENTIALS
# ============================================================
RDS_HOST     = 'endgbv-database.cx62ou6gkd87.us-east-2.rds.amazonaws.com'      
RDS_PORT     = 5432
RDS_DBNAME   = 'postgres'
RDS_USER     = user
RDS_PASSWORD = pw
# ============================================================

conn = psycopg2.connect(
    host=RDS_HOST,
    port=RDS_PORT,
    dbname=RDS_DBNAME,
    user=RDS_USER,
    password=RDS_PASSWORD
)

# %%
df = pd.read_sql(
    '''
    SELECT *
    FROM endgbv
    LIMIT 10
    ;
    ''', conn
)

df.head(10)
# Out:
# C:\Users\helen\AppData\Local\Temp\ipykernel_23244\2297787844.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(
#   Offense Type Report Date  Incident Precinct Code Borough Name  \
# 0          DIR  12/31/2021                      40        BRONX
# 1          DIR  12/31/2021                      40        BRONX
# 2          DIR  12/31/2021                      40        BRONX
# 3          DIR  12/31/2021                      40        BRONX
# 4          DIR  12/31/2021                      40        BRONX
# 5          DIR  12/31/2021                      40        BRONX
# 6          DIR  12/31/2021                      40        BRONX
# 7          DIR  12/31/2021                      40        BRONX
# 8          DIR  12/31/2021                      40        BRONX
# 9          DIR  12/31/2021                      40        BRONX
#
#   Intimate Relationship Flag Victim Race Victim Sex  Victim Reported Age  \
# 0                        YES       WHITE     FEMALE                 31.0
# 1                    MISSING        None       None                  NaN
# 2                         NO       BLACK     FEMALE                 59.0
# 3                    MISSING        None       None                  NaN
# 4                         NO       BLACK     FEMALE                 44.0
# 5                        YES       BLACK     FEMALE                 29.0
# 6                         NO       WHITE       MALE                 19.0
# 7                    MISSING        None       None                  NaN
# 8                    MISSING        None       None                  NaN
# 9                    MISSING        None       None                  NaN
#
#   Suspect Race Suspect Sex Suspect Reported Age  COMMDIST  Poverty  \
# 0        WHITE        MALE                 36.0     201.0      1.0
# 1         None        None                 None     201.0      1.0
# 2        BLACK        MALE                 34.0     201.0      1.0
# 3         None        None                 None     201.0      1.0
# 4        BLACK      FEMALE                 52.0     201.0      1.0
# 5        BLACK        MALE                 39.0     201.0      1.0
# 6        WHITE        MALE                 50.0     201.0      1.0
# 7         None        None                 None     201.0      1.0
# 8         None        None                 None     201.0      1.0
# 9         None        None                 None     201.0      1.0
#
#    Median Income  Unemployment
# 0            1.0           1.0
# 1            1.0           1.0
# 2            1.0           1.0
# 3            1.0           1.0
# 4            1.0           1.0
# 5            1.0           1.0
# 6            1.0           1.0
# 7            1.0           1.0
# 8            1.0           1.0
# 9            1.0           1.0

# %%
conn.close()
print("Connection closed.")
# Out:
# Connection closed.
